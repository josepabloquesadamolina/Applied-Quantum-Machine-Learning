# %% [markdown]
# # Import libraries and modules

# %%
import cv2
import os
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from skimage import io
import scipy as sp
from scipy.optimize import minimize
from matplotlib import transforms
from scipy import ndimage
import time
from numpy import asarray
from numpy import savetxt
import pickle
import h5py 
path=os.getcwd()

# %% [markdown]
# # Relative error evolution

# %%
iters=14

relative_errors_1= np.loadtxt('relative_errors_tot_it_14_1.csv', delimiter=',')
relative_errors_2= np.loadtxt('relative_errors_tot_it_14_2.csv', delimiter=',')
relative_errors_3= np.loadtxt('relative_errors_tot_it_14_3.csv', delimiter=',')
relative_errors_4= np.loadtxt('relative_errors_tot_it_14_4.csv', delimiter=',')
relative_errors_5= np.loadtxt('relative_errors_tot_it_14_5.csv', delimiter=',')


fig, ax = plt.subplots()
ax.plot(list(range(1,iters+1)), relative_errors_1,marker="o", linewidth=0.5, alpha=0.5, label='Simulated annealing')
ax.plot(list(range(1,iters+1)), relative_errors_2,marker="o", linewidth=0.5, alpha=0.5, label='Default annealing')
ax.plot(list(range(1,iters+1)), relative_errors_3,marker="o", linewidth=0.5,alpha=0.5, label='Reverse annealing')
ax.plot(list(range(1,iters+1)), relative_errors_4,marker="o", linewidth=0.5,alpha=0.5, label='Extended annealing')
ax.plot(list(range(1,iters+1)), relative_errors_5,marker="o", linewidth=0.5,alpha=0.5, label='Pause-Quench')
    
    
plt.legend()
ax.set(xlabel='Iterations', ylabel='|| A-BC || / || A ||', title='Relative error evolution')
ax.grid()
plt.show()
fig.savefig("Relative error evolution.png")

print("Relative error for last iteration (Simulated annealing): ",relative_errors_1[13])
print("Relative error for last iteration (Default annealing): ",relative_errors_2[13])
print("Relative error for last iteration (Reverse): ",relative_errors_3[13])
print("Relative error for last iteration (Extended annealing): ",relative_errors_4[13])
print("Relative error for last iteration (Pause-Quench): ",relative_errors_5[13])
# Out:
# <img src="data:image/png;base64,..." width="640">
# Relative error for last iteration (Simulated annealing):  0.08758260965041172
# Relative error for last iteration (Default annealing):  0.14856440599395412
# Relative error for last iteration (Reverse):  0.10368811998207222
# Relative error for last iteration (Extended annealing):  0.14744391388395175
# Relative error for last iteration (Pause-Quench):  0.14902026986204683

# %% [markdown]
# # %Change in B

# %%
iters=14
ChangeB_1= np.loadtxt('%ChangeB_tot_it_14_1.csv', delimiter=',')
ChangeB_2= np.loadtxt('%ChangeB_tot_it_14_2.csv', delimiter=',')
ChangeB_3= np.loadtxt('%ChangeB_tot_it_14_3.csv', delimiter=',')
ChangeB_4= np.loadtxt('%ChangeB_tot_it_14_4.csv', delimiter=',')
ChangeB_5= np.loadtxt('%ChangeB_tot_it_14_5.csv', delimiter=',')



fig, ax = plt.subplots()
ax.plot(list(range(1,iters+1)), ChangeB_1,marker="o", linewidth=0.5, alpha=0.5, label='Simulated annealing')
ax.plot(list(range(1,iters+1)), ChangeB_2,marker="o", linewidth=0.5, alpha=0.5, label='Default annealing')
ax.plot(list(range(1,iters+1)), ChangeB_3,marker="o", linewidth=0.5,alpha=0.5, label='Reverse annealing')
ax.plot(list(range(1,iters+1)), ChangeB_4,marker="o", linewidth=0.5,alpha=0.5, label='Extended annealing')
ax.plot(list(range(1,iters+1)), ChangeB_5,marker="o", linewidth=0.5,alpha=0.5, label='Pause-Quench')
    

plt.legend()
ax.set(xlabel='Iterations', ylabel='%Change in B', title='Iterative improvement of B')
ax.grid()
plt.show()
fig.savefig("Iterative improvement of B.png")

print("%Change in B for last iteration  (Simulated annealing): ",ChangeB_1[13])
print("%Change in B for last iteration  (Default annealing): ",ChangeB_2[13])
print("%Change in B for last iteration (Reverse): ",ChangeB_3[13])
print("%Change in B for last iteration (Extended annealing): ",ChangeB_4[13])
print("%Change in B for last iteration (Pause-Quench): ",ChangeB_5[13])
# Out:
# <img src="data:image/png;base64,..." width="640">
# %Change in B for last iteration  (Simulated annealing):  0.06716552185425922
# %Change in B for last iteration  (Default annealing):  0.41930735204393355
# %Change in B for last iteration (Reverse):  0.09357054285559269
# %Change in B for last iteration (Extended annealing):  0.40392887284002715
# %Change in B for last iteration (Pause-Quench):  0.40138375522632364

# %% [markdown]
# # %Change in C

# %%
iters=14
ChangeC_1= np.loadtxt('%ChangeC_tot_it_14_1.csv', delimiter=',')
ChangeC_2= np.loadtxt('%ChangeC_tot_it_14_2.csv', delimiter=',')
ChangeC_3= np.loadtxt('%ChangeC_tot_it_14_3.csv', delimiter=',')
ChangeC_4= np.loadtxt('%ChangeC_tot_it_14_4.csv', delimiter=',')
ChangeC_5= np.loadtxt('%ChangeC_tot_it_14_5.csv', delimiter=',')



fig, ax = plt.subplots()
ax.plot(list(range(1,iters+1)), ChangeC_1,marker="o", linewidth=0.5, alpha=0.5, label='Simulated annealing')
ax.plot(list(range(1,iters+1)), ChangeC_2,marker="o", linewidth=0.5, alpha=0.5, label='Default annealing')
ax.plot(list(range(1,iters+1)), ChangeC_3,marker="o", linewidth=0.5,alpha=0.5, label='Reverse annealing')
ax.plot(list(range(1,iters+1)), ChangeC_4,marker="o", linewidth=0.5,alpha=0.5, label='Extended annealing')
ax.plot(list(range(1,iters+1)), ChangeC_5,marker="o", linewidth=0.5,alpha=0.5, label='Pause-Quench')
    

plt.legend()
ax.set(xlabel='Iterations', ylabel='%Change in C', title='Iterative improvement of C')
ax.grid()
plt.show()
fig.savefig("Iterative improvement of C.png")

print("%Change in C for last iteration  (Simulated annealing): ",ChangeC_1[13])
print("%Change in C for last iteration  (Default annealing): ",ChangeC_2[13])
print("%Change in C for last iteration (Reverse): ",ChangeC_3[13])
print("%Change in C for last iteration (Extended annealing): ",ChangeC_4[13])
print("%Change in C for last iteration (Pause-Quench): ",ChangeC_5[13])
# Out:
# <img src="data:image/png;base64,..." width="640">
# %Change in C for last iteration  (Simulated annealing):  0.001142857142857143
# %Change in C for last iteration  (Default annealing):  0.3554285714285714
# %Change in C for last iteration (Reverse):  0.0014285714285714286
# %Change in C for last iteration (Extended annealing):  0.3628571428571429
# %Change in C for last iteration (Pause-Quench):  0.36857142857142855
